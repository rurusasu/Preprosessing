# %%
# CC-Netを Git よりダウンロード
# !git clone https://github.com/facebookresearch/cc_net.git ../lib/cc_net
# Out:
# Cloning into '../lib/cc_net'...
# remote: Enumerating objects: 551, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 551 (delta 124), reused 116 (delta 112), pack-reused 414
# Receiving objects: 100% (551/551), 288.12 KiB | 1.78 MiB/s, done.
# Resolving deltas: 100% (382/382), done.

# %%
# パッケージのインストール
# !poetry add transformers torch
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   • transformers
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Using version ^2.0.1 for torch
#
# Updating dependencies
# Resolving dependencies... (3.2s)Resolving dependencies... (2.4s)
#
# Writing lock file
#
# Package operations: 4 installs, 0 updates, 0 removals
#
#   • Installing mpmath (1.3.0): Pending...
#   • Installing mpmath (1.3.0): Downloading... 0%
#   • Installing mpmath (1.3.0): Downloading... 70%
#   • Installing mpmath (1.3.0): Downloading... 100%
#   • Installing mpmath (1.3.0): Installing...
#   • Installing mpmath (1.3.0)
#   • Installing networkx (3.1): Pending...
#   • Installing sympy (1.12): Pending...
#   • Installing sympy (1.12): Downloading... 0%
#   • Installing sympy (1.12): Downloading... 10%
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /workspaces/Preprosessing/.venv/lib/python3.10/site-packages/torch/__init__.py:168, in _load_global_deps()
#     167 try:
# --> 168     ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#     169 except OSError as err:
#     170     # Can only happen for wheel with cuda libs as PYPI deps
#     171     # As PyTorch is not purelib, but nvidia-*-cu11 is
#
# File /usr/local/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#
# OSError: libcurand.so.10: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...
